# %%
# coding: utf-8


import os
import sys
import re
import string
import pandas as pd
import numpy as np
from copy import deepcopy
from updatedb import UpdateDB
from collections import Counter, defaultdict
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
# =========================================== 获得日期数据 ========================================================================

updb = UpdateDB('10.24.224.249','fineng','123456')
index = updb.pull_index(['000300.SH']).loc['20100101':].reset_index().rename(columns={'TRADE_DT':'date'}).sort_values('date')
index['next_date'] = index['date'].shift(-1)

code_name = updb.pull_data_accor_date('MyAShareDescription','wind',set_index=False).set_index('S_INFO_WINDCODE')
output_dir = 'output0331'
# =========================================== 处理新闻数据 ========================================================================

newsfiles = os.listdir('../news2')
newsfiles = list(filter(lambda x: x.split('.')[1][0]=='S', newsfiles))

def get_price(symbol):
    # 计算股票的涨跌幅
    price = updb.pull_stocks([symbol], startT='20100101').sort_index().reset_index().rename(columns={'TRADE_DT':'date',symbol:'close'})
    price['CloseRet_t-2_t+1'] = price['close'].shift(-1) / price['close'].shift(2)-1
    price['CloseRet_t-1_t+1'] = price['close'].shift(-1) / price['close'].shift(1)-1
    price['CloseRet_t_t+1'] = price['close'].shift(-1) / price['close']-1
    price['CloseRet_t-1_t'] = price['close'] / price['close'].shift(1)-1
    return price

def get_label(df, indicators, thresholds):
    # 根据涨跌幅筛选有用新闻并设置标签
    def assign(df, indicator,threshold):
        df['label'] = np.nan
        df.loc[df[indicator]>threshold,'label'] = '1'
        df.loc[df[indicator]<1./(1+threshold)-1,'label'] = '0'
        return df[['date','label','title']]
    dfs = [assign(deepcopy(df),ind, thr) for ind,thr in zip(indicators,thresholds)]
    return dfs

def loadfiles(symbol):
    files = os.listdir('../news2/%s/' % symbol)
    news = []
    for f in files:
        try:
            news_f = pd.read_csv('../news2/%s/%s' % (symbol,f), dtype={'date':str})[['date','title','time','url']]
            news.append(news_f)
        except:
            continue
    if len(news) > 0:
        news = pd.concat(news)
        news['urlid'] = [','.join(url.split(',')[-2:]) for url in news['url']]
        news = news.drop_duplicates('urlid',keep='last').drop('url',axis=1)
        if len(news) > 0:
            return news
    return None

def process(symbol, indicators, thresholds, first=False):
    # 总的处理流程，调用get_price，get_label等功能函数
    news = loadfiles(symbol)
    if news is None:
        return
    # news = pd.read_csv('news/%s.csv' % symbol,dtype={'date':str})[['date','title','time']]

    news = news.dropna()
    news = news.sort_values('date')
    # 剔除无用消息
    nonsense=['融资融券信息','融资净偿还','融资净买入','融券净偿还','大宗交易','今日超大单流','龙虎榜','下跌','上涨','跌幅','涨幅','涨停','跌停',
              '大涨','大跌','跳水','盘中','融资余额','反弹','回调','火箭发射','投资者关系']
    is_useful = np.array([not any(bool(re.search(w,l)) for w in nonsense) for l in news['title'].values])
    news = news[is_useful]
    news['title'] = [s.replace(code_name.loc[symbol].values[0],'') for s in news['title']]
    news = news.loc[[len(s)>3 for s in news['title']]]
    # 对15:00:00以后的新闻把日期调整到下一个交易日    
    news['date'] = list(map(lambda x:x.replace('-',''), news['date'].values))
    news = news.merge(index[['date','next_date']],on='date',how='left')
    news.loc[news['time']>'13:00:00','date'] = np.nan
    news['date'] = news['date'].fillna(news['next_date'])
    try:
        price = get_price(symbol)
    except:
        return
    print(news)
    news = news.merge(price)
    dfs = get_label(news, indicators, thresholds)
    
    # 存储数据
    for ind,df in zip(indicators, dfs):
        df['code'] = symbol
        if not os.path.exists('%s/clean/' % output_dir):
            os.makedirs('%s/clean/' % output_dir)
        if first:
            df.to_csv('%s/clean/%s.csv' % (output_dir, ind), index=False)
        else:
            df.to_csv('%s/clean/%s.csv' % (output_dir, ind), mode='a', header=False,  index=False)

def split_train_test(filenames, sep_date, dev_size=0.1):
    
    for filename in filenames:
        print('shuffle and split %s' % filename)
        if not os.path.exists('%s/shuffle/%s' % (output_dir, filename)):
            os.makedirs('%s/shuffle/%s' % (output_dir, filename))

        df = pd.read_csv('%s/clean/%s.csv' % (output_dir, filename),dtype={'date':str,'label':str})
        idx_train = (df['date']<sep_date) & (~df['label'].isnull())
        idx_test = (df['date']>=sep_date) & (~df['label'].isnull())
        num_train = int(sum(idx_train) * (1-dev_size))
        # df = shuffle(df)
        # x_data, y_data = df['title'], df['label']
        # x_train, x_test, y_train, y_test = train_test_split(df['title'], df['label'], test_size=test_size, shuffle=True)
        
        train = shuffle(shuffle(shuffle(df.loc[idx_train][['label','title']].rename(columns={'title':'x_train'}), random_state=0),random_state=0),random_state=0)
        print(len(train[train['label']==1]) / len(train))
        train.iloc[:num_train].to_csv('%s/shuffle/%s/train.csv' % (output_dir, filename), index=False, sep='\t')
        train.iloc[num_train:].rename(columns={'x_train':'x_valid'}).to_csv('%s/shuffle/%s/dev.csv' % (output_dir, filename), index=False, sep='\t')
        
        test = pd.concat([shuffle(df.loc[idx_test]), df.loc[~idx_test]]).rename(columns={'title':'x_test'})
        test[['label','x_test']].to_csv('%s/shuffle/%s/test.csv' % (output_dir, filename), index=False, sep='\t')
        test[['date','code']].to_csv('%s/shuffle/%s/test_date.csv' % (output_dir, filename), index=False, sep='\t')

    
indicators = ['CloseRet_t-2_t+1','CloseRet_t-1_t+1','CloseRet_t_t+1']
thresholds = [0.1,0.08,0.05]
sep_date='20190101'
# nf = newsfiles[0]
# process(nf,indicators, thresholds, first=True)
# for i,nf in enumerate(newsfiles[1:]):
#     if (len(nf)==9):
#         print('processing %s %d/%d' % (nf, i, len(newsfiles)))
#         process(nf,indicators, thresholds, first=False)

# split_train_test(indicators,sep_date)

# %%
process('.SZ',indicators, thresholds, first=False)
# Out:
#           date                                           title      time  \
# 0     20110513                             深发展A重大资产重组获通过 13日复牌  18:25:54
# 1     20110513                         证监会通过“平深恋”重组方案 深发展13日复牌  20:54:24
# 2     20110513                                 “平深恋”获批 深发展A今复牌  09:25:28
# 3     20110517                       平深恋获批：26城380网点大整合 深发展之名不变  13:17:22
# 4     20110517                          缝合平安深发展 年底是“两家变一家”最后期限  16:22:42
# 5     20110517                                 平深恋“领证” 深发展复牌微涨  00:10:13
# 6     20110526                          深发展保资本充足率不分红 董事会称考虑再融资  09:21:33
# 7     20110526                          理查德力推最佳银行战略 深发展零售步随平安？  04:51:48
# 8     20110526                            保资本充足率不分红 深发展考虑再“补血”  05:50:52
# 9     20110530                                   深发展董事长：正考虑再融资  13:28:40
# 10    20110608                                  深发展通过盈利厘定等三项议案  08:38:05
# 11    20110613                                 浦发银行：7月与移动“深发展”  23:38:10
# 12    20110615                               股东会延期 小股东争议深发展表决权  06:35:40
# 13    20110627                           深发展绿色信贷排名倒数第一 变相支持高污染  13:13:48
# 14    20110630                               深发展收购已获批 暂时保持独立运作  19:23:33
# 15    20110630                                   平深恋“过会” 深发展控股  17:26:13
# 16    20110630                                  深发展平台贷占比降至5.5%  05:06:20
# 17    20110630                                     深发展或将定向增发募资  08:53:02
# 18    20110705                                 深发展：发令枪响 直奔黄金未来  13:39:41
# 19    20110705                            “嫁入”平安 深发展谋划5年奠定市场地位  02:27:43
# 20    20110706                                      深发展本月确定收购日  15:47:21
# 21    20110706                                 深发展或通过增发提高资本充足率  09:42:01
# 22         NaN                                 两年收官 深发展整合时间表起底  20:44:55
# 23    20110713                              深发展A上半年业绩预增50%-60%  19:04:42
# 24    20110713                               农行和深发展上半年净利预增逾45%  09:48:54
# 25    20110714                                  农行和深发展预报中期业绩靓丽  13:04:06
# 26    20110714                        农行中期净利预增45% 深发展A净利预增超50%  14:25:35
# 27    20110714                                    深发展上半年净利预增五成  09:22:38
# 28    20110714                       深发展上半年净利预增五成 净利润或达到48.53亿  10:45:09
# 29    20110719                                  深发展成为航运运价交易结算行  10:31:13
# ...        ...                                             ...       ...
# 1566  20200214                          ：2019年净利282亿元 同比增13.6%  19:00:02
# 1567  20200214                        去年净利润282亿元增13% 谢永林称成绩单满意  11:37:54
# 1568  20200217                     2019年净利润281.95亿元 多项关键指标稳健增长  18:57:29
# 1569  20200217                             召开“数字发布会” 2019年业绩双增  19:15:35
# 1570  20200217                             净利润重回两位数增长 对公业务重启扩张  20:04:28
# 1571  20200217                          利润增长率近三年最高 转型动能转化为实际业绩  20:14:16
# 1572  20200217  高管戴口罩直播3小时 超27万人围观！最特殊业绩发布会 谢永林详解“三大动能”和“三张名片”  21:18:20
# 1573  20200217                         股价暴涨77%背后：营收净利增速创转型以来新高  18:51:53
# 1574  20200217                 疫情对资产质量有何影响、零售与对公如何协同…..管理层这样回应  18:36:08
# 1575  20200217                              谢永林：经过转型已经形成三大关键动能  15:39:49
# 1576  20200217                           上市银行首份年报披露 去年净利润约282亿  16:17:35
# 1577  20200214                                 2019年 净利增长13.6%  08:54:30
# 1578  20200214                           平安领衔首份银行年报 行业整体回暖风险仍存  04:53:52
# 1579  20200214                                        拟提拔两位副行长  03:02:34
# 1580  20200214                     上市银行进入“年报时间” 去年净利润同比增长13.6%  01:32:43
# 1581  20200217                            董事长谢永林：着力打造数字银行等三张名片  22:18:39
# 1582       NaN                           情人节开年报发布会 谢永林亲述三个走心故事  19:53:02
# 1583  20200215                     上市银行首份年报出炉 2019年净利润同比增13.6%  05:34:32
# 1584  20200217                                率先披露 上市银行2019年年报  05:56:30
# 1585  20200218                                 一周内认购6.7亿元疫情防控债  18:39:20
# 1586  20200217                                        去年净利增14%  05:53:28
# 1587  20200218                   净利增逾13%创转型新高 “大零售大对公”均衡格局逐步形成  10:44:15
# 1588  20200219                      300亿元永续债三日后发行 票面利率能否创新低受关注  13:08:43
# 1589  20200218                                     拟发行300亿元永续债  12:11:09
# 1590  20200219                     银行业首份年报：零售业务快速增长 个贷不良率上升需关注  09:08:22
# 1591  20200219                          利润增长率近三年最高 转型动能转化为实际业绩  04:35:03
# 1592  20200220                       2019年净利润同比增13.6% 零售转型深入推进  04:49:31
# 1593  20200226                        对公发力：张小璐详解交易银行“三张名片”经营策略  17:53:38
# 1594  20200303                              又现百万罚单 涉及信贷、保险代销业务  19:55:15
# 1595  20200303                                  ：营收较快增长 盈利增速放缓  00:29:32
#
#                       urlid next_date
# 0      000001,38202342.html  20110513
# 1      000001,38207837.html  20110513
# 2      000001,38220721.html  20110516
# 3      000001,38342830.html  20110517
# 4      000001,38361114.html  20110517
# 5      000001,38375656.html  20110518
# 6      000001,38897280.html  20110527
# 7      000001,38891890.html  20110527
# 8      000001,38892013.html  20110527
# 9      000001,39004978.html  20110530
# 10     000001,39428465.html  20110609
# 11     000001,39592836.html  20110613
# 12     000001,39725941.html  20110616
# 13     000001,40154506.html  20110627
# 14     000001,40353994.html  20110630
# 15     000001,40351269.html  20110630
# 16     000001,40362075.html  20110701
# 17     000001,40364792.html  20110701
# 18     000001,40527575.html  20110705
# 19     000001,40554670.html  20110706
# 20     000001,40596646.html  20110706
# 21     000001,40616438.html  20110707
# 22     000001,40808796.html       NaN
# 23     000001,40912583.html  20110713
# 24     000001,40927031.html  20110714
# 25     000001,40947453.html  20110714
# 26     000001,40959228.html  20110714
# 27     000001,40986980.html  20110715
# 28     000001,40999607.html  20110715
# 29     000001,41220823.html  20110720
# ...                     ...       ...
# 1566  000001,903624068.html  20200214
# 1567  000001,903804083.html  20200217
# 1568  000001,903945330.html  20200217
# 1569  000001,903948233.html  20200217
# 1570  000001,903956285.html  20200217
# 1571  000001,903957549.html  20200217
# 1572  000001,903966067.html  20200217
# 1573  000001,903944427.html  20200217
# 1574  000001,903941978.html  20200217
# 1575  000001,903915763.html  20200217
# 1576  000001,903922110.html  20200217
# 1577  000001,903688476.html  20200217
# 1578  000001,903673760.html  20200217
# 1579  000001,903670494.html  20200217
# 1580  000001,903668263.html  20200217
# 1581  000001,903973252.html  20200217
# 1582  000001,904046710.html       NaN
# 1583  000001,903992625.html       NaN
# 1584  000001,904158355.html  20200218
# 1585  000001,904428910.html  20200218
# 1586  000001,904158295.html  20200218
# 1587  000001,904566589.html  20200219
# 1588  000001,904618412.html  20200219
# 1589  000001,904606822.html  20200219
# 1590  000001,904819153.html  20200220
# 1591  000001,904798430.html  20200220
# 1592  000001,905148384.html  20200221
# 1593  000001,906855784.html  20200226
# 1594  000001,908756179.html  20200303
# 1595  000001,908805568.html  20200304
#
# [1596 rows x 5 columns]

# %%
df = pd.read_csv('../output0331/clean/CloseRet_t-2_t+1.csv')#.sort_values('date')
df[df['date']==20200123].to_excel('20200123.xlsx',engine='xlsxwriter')
