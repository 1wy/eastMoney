# %% [markdown]
# # Study the impact of the news

# %%
import os
import sys
import re
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from pyhanlp import *
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
import matplotlib.pyplot as plt
from gensim import corpora
from collections import defaultdict
from snownlp import SnowNLP
from updatedb import UpdateDB
from copy import deepcopy
HanLP.Config.ShowTermNature = False
# %matplotlib inline

# %% [markdown]
# ### 1. 处理价格数据

# %%
updb = UpdateDB('10.24.224.249','fineng','123456')
index = updb.pull_index(['000300.SH']).loc['20100101':].reset_index().rename(columns={'TRADE_DT':'date'}).sort_values('date')
index['next_date'] = index['date'].shift(-1)
index.head()
# Out:
# S_INFO_WINDCODE      date  000300.SH next_date
# 0                20100104   3535.229  20100105
# 1                20100105   3564.038  20100106
# 2                20100106   3541.727  20100107
# 3                20100107   3471.456  20100108
# 4                20100108   3480.130  20100111

# %%
code_name = updb.pull_data_accor_date('MyAShareDescription','wind',set_index=False).set_index('S_INFO_WINDCODE')
code_name
# Out:
#                 S_INFO_NAME
# S_INFO_WINDCODE
# 000001.SZ              平安银行
# 000002.SZ               万科A
# 000003.SZ         PT金田A(退市)
# 000004.SZ              国农科技
# 000005.SZ              世纪星源
# 000006.SZ              深振业A
# 000007.SZ               全新好
# 000008.SZ              神州高铁
# 000009.SZ              中国宝安
# 000010.SZ             *ST美丽
# 000011.SZ              深物业A
# 000012.SZ               南玻A
# 000013.SZ        *ST石化A(退市)
# 000014.SZ              沙河股份
# 000015.SZ         PT中浩A(退市)
# 000016.SZ              深康佳A
# 000017.SZ              深中华A
# 000018.SZ              神城A退
# 000019.SZ              深粮控股
# 000020.SZ              深华发A
# 000021.SZ               深科技
# 000023.SZ              深天地A
# 000024.SZ          招商地产(退市)
# 000025.SZ               特力A
# 000026.SZ              飞亚达A
# 000027.SZ              深圳能源
# 000028.SZ              国药一致
# 000029.SZ              深深房A
# 000030.SZ              富奥股份
# 000031.SZ               大悦城
# ...                     ...
# A19423.SH              艾迪药业
# A19424.SZ              兆龙互连
# A19425.SZ              顺控发展
# A19426.SZ               狄耐克
# A19427.SH              松井新材
# A19428.SH              金博股份
# A19429.SH              信大捷安
# A19430.SZ              志特新材
# A19431.SH              盛剑环境
# A19432.SH              恒誉环保
# A19433.SH              京沪高铁
# A19434.SH              路德环境
# A19435.SH              三生国健
# A19436.SH              敏芯股份
# A19437.SH              键凯科技
# A19438.SZ              南凌科技
# A19439.SZ              卓创资讯
# A19440.SH              微创网络
# A19441.SH              国盛智科
# A19442.SZ              南山智尚
# A19443.SZ               南极光
# A19444.SZ              亿田股份
# A19445.SH              精英数智
# A19446.SH              铁科轨道
# A19447.SH              合肥江航
# A19448.SH              传神语联
# A19449.SH              德才装饰
# A19450.SH              龙高股份
# A19451.SZ              美能能源
# T00018.SH          上港集箱(退市)
#
# [5223 rows x 1 columns]

# %% [markdown]
# ## 2. 处理新闻数据

# %%
# newsfiles = os.listdir('../news2/000001.SZ')
# newsfiles = list(filter(lambda x: x.split('.')[1][0]=='S', newsfiles))
symbol = '000001.SZ'
files = os.listdir('../news2/%s/' % symbol)
news = pd.concat([pd.read_csv('../news2/%s/%s' % (symbol,f), dtype={'date':str})[['date','title','time']] for f in files])
# files
# news = pd.read_csv('../news2/%s/%s' % (symbol, files[0]),dtype={'date':str})[['date','title','time']]
news
# Out:
#            date                                   title      time
# 0    2020-02-18          平安银行300亿元永续债三日后发行 票面利率能否创新低受关注  13:08:43
# 1    2020-02-19              平安银行利润增长率近三年最高 转型动能转化为实际业绩  04:35:03
# 2    2020-02-19           平安银行：连续3日融资净买入累计1.24亿元（02-18）  08:53:33
# 3    2020-02-19         银行业首份年报：平安银行零售业务快速增长 个贷不良率上升需关注  09:08:22
# 4    2020-02-19               平安银行(000001)融资融券信息(02-18)  09:18:04
# 5    2020-02-20           平安银行2019年净利润同比增13.6% 零售转型深入推进  04:49:31
# 6    2020-02-06             平安银行获深股通连续3日净买入 累计净买入7.54亿元  18:52:48
# 7    2018-08-03               平安银行(000001)融资融券信息(08-02)  09:57:04
# 8    2018-10-09               平安银行(000001)融资融券信息(10-08)  08:53:42
# 9    2018-11-30               平安银行(000001)融资融券信息(11-29)  08:39:39
# 10   2019-01-22                 平安银行发布公开发行可转换公司债券网上中签结果  17:57:04
# 11   2019-03-19                 平安银行大连两宗违规遭罚 销售基金代填风险问卷  09:28:35
# 12   2019-05-31        平安银行董事长谢永林：平安集团团体综合金融业务将以银行为核心展开  02:53:33
# 13   2019-08-08   平安银行交出三年来最好半年报！零售客户数量突破9000万 私行用户增近三成  06:59:57
# 14   2019-08-29               平安银行(000001)融资融券信息(08-28)  09:06:09
# 15   2019-10-17               平安银行(000001)融资融券信息(10-16)  09:22:57
# 16   2019-10-17                 平安银行行长助理兼上海分行行长冷培栋被带走调查  13:46:12
# 17   2019-11-20               平安银行(000001)融资融券信息(11-19)  09:18:14
# 18   2019-11-20     沪深两市11月20日63只个股发生83笔大宗交易 共成交32.72亿元  17:45:51
# 19   2019-11-21               平安银行(000001)融资融券信息(11-20)  09:05:17
# 20   2019-11-21     沪深两市11月21日54只个股发生90笔大宗交易 共成交15.11亿元  18:00:29
# 21   2019-11-21     平安银行11月21日发生1笔大宗交易价格14.27元 折价10.03%  16:46:52
# 22   2019-11-22               平安银行(000001)融资融券信息(11-21)  09:04:35
# 23   2019-11-22              陆敏接棒平安首席保险业务执行官 李源祥候任友邦CEO  17:48:57
# 24   2019-11-22      沪深两市11月22日37只个股发生50笔大宗交易 共成交9.45亿元  17:49:47
# 25   2019-11-25               平安银行(000001)融资融券信息(11-22)  09:03:31
# 26   2019-11-25     平安银行11月25日发生1笔大宗交易价格14.04元 折价11.14%  17:31:49
# 27   2019-11-25     沪深两市11月25日48只个股发生81笔大宗交易 共成交20.93亿元  17:32:58
# 28   2019-11-26               平安银行(000001)融资融券信息(11-25)  09:03:46
# 29   2019-11-26     沪深两市11月26日42只个股发生65笔大宗交易 共成交12.47亿元  18:02:59
# ..          ...                                     ...       ...
# 847  2020-02-15         上市银行首份年报出炉 平安银行2019年净利润同比增13.6%  05:34:32
# 848  2020-02-15               平安银行情人节开年报发布会 谢永林亲述三个走心故事  19:53:02
# 849  2020-02-17                    平安银行率先披露 上市银行2019年年报  05:56:30
# 850  2020-02-17                            平安银行去年净利增14%  05:53:28
# 851  2020-02-17   平安银行：融资净买入590.86万元，融资余额33.25亿元（02-14）  09:09:09
# 852  2020-02-17               平安银行(000001)融资融券信息(02-14)  09:13:11
# 853  2020-02-17                     平安银行一周内认购6.7亿元疫情防控债  18:39:20
# 854  2020-02-18     平安银行：融资净买入1.08亿元，融资余额34.33亿元（02-17）  08:48:06
# 855  2020-02-18               平安银行(000001)融资融券信息(02-17)  09:09:31
# 856  2020-02-18       平安银行净利增逾13%创转型新高 “大零售大对公”均衡格局逐步形成  10:44:15
# 857  2020-02-18                         平安银行拟发行300亿元永续债  12:11:09
# 858  2020-02-18          平安银行300亿元永续债三日后发行 票面利率能否创新低受关注  13:08:43
# 859  2020-02-19              平安银行利润增长率近三年最高 转型动能转化为实际业绩  04:35:03
# 860  2020-02-17     平安银行02月17日发生1笔大宗交易价格13.53元 折价11.97%  16:49:41
# 861  2020-02-19           平安银行：连续3日融资净买入累计1.24亿元（02-18）  08:53:33
# 862  2020-02-19         银行业首份年报：平安银行零售业务快速增长 个贷不良率上升需关注  09:08:22
# 863  2020-02-19               平安银行(000001)融资融券信息(02-18)  09:18:04
# 864  2020-02-20           平安银行2019年净利润同比增13.6% 零售转型深入推进  04:49:31
# 865  2020-02-20      平安银行：融资净偿还8393.31万元，两市排名第14（02-19）  08:54:37
# 866  2020-02-20               平安银行(000001)融资融券信息(02-19)  09:17:17
# 867  2020-02-21   平安银行：融资净买入2110.69万元，融资余额33.8亿元（02-20）  09:02:15
# 868  2020-02-21               平安银行(000001)融资融券信息(02-20)  09:09:15
# 869  2020-02-21      平安银行02月21日发生1笔大宗交易价格14.03元 折价9.95%  16:49:14
# 870  2020-02-24   平安银行：融资净偿还819.59万元，融资余额33.72亿元（02-21）  08:48:06
# 871  2020-02-24               平安银行(000001)融资融券信息(02-21)  09:09:29
# 872  2020-02-25   平安银行：融资净偿还694.93万元，融资余额33.65亿元（02-24）  09:06:15
# 873  2020-02-25               平安银行(000001)融资融券信息(02-24)  09:26:18
# 874  2020-02-28               平安银行(000001)融资融券信息(02-27)  08:54:51
# 875  2020-02-28  平安银行：融资净偿还7596.71万元，融资余额33.81亿元（02-27）  09:18:55
# 876  2020-03-02  平安银行：融资净买入3208.79万元，融资余额34.13亿元（02-28）  09:02:52
#
# [3638 rows x 3 columns]

# %%
newsfiles = os.listdir('../news')
newsfiles = list(filter(lambda x: x.split('.')[1][0]=='S', newsfiles))
newsfiles
# Out:
# ['002551.SZ.csv',
#  '000935.SZ.csv',
#  '603798.SH.csv',
#  '600518.SH.csv',
#  '300515.SZ.csv',
#  '300274.SZ.csv',
#  '603567.SH.csv',
#  '002030.SZ.csv',
#  '603800.SH.csv',
#  '300038.SZ.csv',
#  '000597.SZ.csv',
#  '300167.SZ.csv',
#  '601811.SH.csv',
#  '600507.SH.csv',
#  '603638.SH.csv',
#  '603181.SH.csv',
#  '300476.SZ.csv',
#  '300341.SZ.csv',
#  '002438.SZ.csv',
#  '300470.SZ.csv',
#  '300517.SZ.csv',
#  '300406.SZ.csv',
#  '603309.SH.csv',
#  '603660.SH.csv',
#  '300044.SZ.csv',
#  '002309.SZ.csv',
#  '300622.SZ.csv',
#  '300391.SZ.csv',
#  '300053.SZ.csv',
#  '300117.SZ.csv',
#  '600038.SH.csv',
#  '600589.SH.csv',
#  '601388.SH.csv',
#  '600653.SH.csv',
#  '600526.SH.csv',
#  '300711.SZ.csv',
#  '000858.SZ.csv',
#  '002387.SZ.csv',
#  '300737.SZ.csv',
#  '300007.SZ.csv',
#  '600289.SH.csv',
#  '601216.SH.csv',
#  '300400.SZ.csv',
#  '600774.SH.csv',
#  '603908.SH.csv',
#  '000987.SZ.csv',
#  '300636.SZ.csv',
#  '603650.SH.csv',
#  '600798.SH.csv',
#  '603321.SH.csv',
#  '300556.SZ.csv',
#  '000657.SZ.csv',
#  '600648.SH.csv',
#  '600012.SH.csv',
#  '600877.SH.csv',
#  '000823.SZ.csv',
#  '600831.SH.csv',
#  '300516.SZ.csv',
#  '601288.SH.csv',
#  '000968.SZ.csv',
#  '600225.SH.csv',
#  '603909.SH.csv',
#  '002533.SZ.csv',
#  '600281.SH.csv',
#  '603036.SH.csv',
#  '300365.SZ.csv',
#  '300708.SZ.csv',
#  '300168.SZ.csv',
#  '600400.SH.csv',
#  '002569.SZ.csv',
#  '000852.SZ.csv',
#  '000757.SZ.csv',
#  '300076.SZ.csv',
#  '300393.SZ.csv',
#  '603160.SH.csv',
#  '300462.SZ.csv',
#  '600962.SH.csv',
#  '000059.SZ.csv',
#  '002333.SZ.csv',
#  '600630.SH.csv',
#  '601398.SH.csv',
#  '300610.SZ.csv',
#  '300279.SZ.csv',
#  '600606.SH.csv',
#  '600257.SH.csv',
#  '002829.SZ.csv',
#  '002274.SZ.csv',
#  '600733.SH.csv',
#  '300508.SZ.csv',
#  '600099.SH.csv',
#  '600121.SH.csv',
#  '603214.SH.csv',
#  '002645.SZ.csv',
#  '000806.SZ.csv',
#  '000800.SZ.csv',
#  '300075.SZ.csv',
#  '300107.SZ.csv',
#  '002927.SZ.csv',
#  '300083.SZ.csv',
#  '600555.SH.csv',
#  '600350.SH.csv',
#  '600291.SH.csv',
#  '601333.SH.csv',
#  '002480.SZ.csv',
#  '600629.SH.csv',
#  '600303.SH.csv',
#  '002515.SZ.csv',
#  '603066.SH.csv',
#  '002299.SZ.csv',
#  '300047.SZ.csv',
#  '002475.SZ.csv',
#  '600361.SH.csv',
#  '002891.SZ.csv',
#  '600335.SH.csv',
#  '002909.SZ.csv',
#  '600191.SH.csv',
#  '300417.SZ.csv',
#  '300359.SZ.csv',
#  '600095.SH.csv',
#  '002864.SZ.csv',
#  '000584.SZ.csv',
#  '300296.SZ.csv',
#  '600366.SH.csv',
#  '600712.SH.csv',
#  '600856.SH.csv',
#  '300448.SZ.csv',
#  '300579.SZ.csv',
#  '300721.SZ.csv',
#  '300479.SZ.csv',
#  '300606.SZ.csv',
#  '603329.SH.csv',
#  '002747.SZ.csv',
#  '603286.SH.csv',
#  '002386.SZ.csv',
#  '300576.SZ.csv',
#  '600590.SH.csv',
#  '300779.SZ.csv',
#  '300731.SZ.csv',
#  '300440.SZ.csv',
#  '002530.SZ.csv',
#  '002483.SZ.csv',
#  '600890.SH.csv',
#  '002677.SZ.csv',
#  '300513.SZ.csv',
#  '300304.SZ.csv',
#  '603196.SH.csv',
#  '600111.SH.csv',
#  '000837.SZ.csv',
#  '300463.SZ.csv',
#  '600815.SH.csv',
#  '002453.SZ.csv',
#  '002036.SZ.csv',
#  '600743.SH.csv',
#  '002195.SZ.csv',
#  '000712.SZ.csv',
#  '002765.SZ.csv',
#  '600573.SH.csv',
#  '300377.SZ.csv',
#  '600369.SH.csv',
#  '002931.SZ.csv',
#  '002529.SZ.csv',
#  '600428.SH.csv',
#  '600658.SH.csv',
#  '600715.SH.csv',
#  '600397.SH.csv',
#  '002155.SZ.csv',
#  '603086.SH.csv',
#  '600375.SH.csv',
#  '600811.SH.csv',
#  '601789.SH.csv',
#  '600280.SH.csv',
#  '002675.SZ.csv',
#  '600557.SH.csv',
#  '002319.SZ.csv',
#  '002405.SZ.csv',
#  '002650.SZ.csv',
#  '300383.SZ.csv',
#  '600195.SH.csv',
#  '600103.SH.csv',
#  '601869.SH.csv',
#  '600354.SH.csv',
#  '603067.SH.csv',
#  '300103.SZ.csv',
#  '002926.SZ.csv',
#  '600268.SH.csv',
#  '002135.SZ.csv',
#  '002378.SZ.csv',
#  '002558.SZ.csv',
#  '002930.SZ.csv',
#  '000826.SZ.csv',
#  '000333.SZ.csv',
#  '600188.SH.csv',
#  '601606.SH.csv',
#  '002286.SZ.csv',
#  '601000.SH.csv',
#  '002027.SZ.csv',
#  '300290.SZ.csv',
#  '000766.SZ.csv',
#  '002278.SZ.csv',
#  '002697.SZ.csv',
#  '600222.SH.csv',
#  '603041.SH.csv',
#  '002666.SZ.csv',
#  '000516.SZ.csv',
#  '002896.SZ.csv',
#  '000613.SZ.csv',
#  '000753.SZ.csv',
#  '000869.SZ.csv',
#  '603326.SH.csv',
#  '600305.SH.csv',
#  '300649.SZ.csv',
#  '002736.SZ.csv',
#  '000428.SZ.csv',
#  '002847.SZ.csv',
#  '300264.SZ.csv',
#  '601877.SH.csv',
#  '600685.SH.csv',
#  '600800.SH.csv',
#  '002373.SZ.csv',
#  '600005.SH.csv',
#  '600199.SH.csv',
#  '603986.SH.csv',
#  '002861.SZ.csv',
#  '600618.SH.csv',
#  '601598.SH.csv',
#  '002081.SZ.csv',
#  '002521.SZ.csv',
#  '600900.SH.csv',
#  '600654.SH.csv',
#  '002132.SZ.csv',
#  '601163.SH.csv',
#  '600112.SH.csv',
#  '601126.SH.csv',
#  '600182.SH.csv',
#  '600476.SH.csv',
#  '300554.SZ.csv',
#  '600879.SH.csv',
#  '600847.SH.csv',
#  '600779.SH.csv',
#  '002667.SZ.csv',
#  '600277.SH.csv',
#  '000886.SZ.csv',
#  '600309.SH.csv',
#  '002578.SZ.csv',
#  '300068.SZ.csv',
#  '603278.SH.csv',
#  '300196.SZ.csv',
#  '000518.SZ.csv',
#  '002634.SZ.csv',
#  '000729.SZ.csv',
#  '601012.SH.csv',
#  '002424.SZ.csv',
#  '300005.SZ.csv',
#  '002316.SZ.csv',
#  '300474.SZ.csv',
#  '002331.SZ.csv',
#  '600232.SH.csv',
#  '600973.SH.csv',
#  '002647.SZ.csv',
#  '000733.SZ.csv',
#  '300099.SZ.csv',
#  '603239.SH.csv',
#  '601860.SH.csv',
#  '600478.SH.csv',
#  '002104.SZ.csv',
#  '600850.SH.csv',
#  '300140.SZ.csv',
#  '600088.SH.csv',
#  '600323.SH.csv',
#  '603139.SH.csv',
#  '002422.SZ.csv',
#  '300581.SZ.csv',
#  '002158.SZ.csv',
#  '002711.SZ.csv',
#  '600132.SH.csv',
#  '601599.SH.csv',
#  '600449.SH.csv',
#  '600240.SH.csv',
#  '002638.SZ.csv',
#  '603536.SH.csv',
#  '600120.SH.csv',
#  '002886.SZ.csv',
#  '600675.SH.csv',
#  '002771.SZ.csv',
#  '601001.SH.csv',
#  '300246.SZ.csv',
#  '002517.SZ.csv',
#  '002788.SZ.csv',
#  '002164.SZ.csv',
#  '600495.SH.csv',
#  '603377.SH.csv',
#  '300119.SZ.csv',
#  '300270.SZ.csv',
#  '000404.SZ.csv',
#  '300502.SZ.csv',
#  '002412.SZ.csv',
#  '600970.SH.csv',
#  '600891.SH.csv',
#  '600623.SH.csv',
#  '002554.SZ.csv',
#  '002820.SZ.csv',
#  '600828.SH.csv',
#  '300685.SZ.csv',
#  '002128.SZ.csv',
#  '603882.SH.csv',
#  '601579.SH.csv',
#  '300750.SZ.csv',
#  '002341.SZ.csv',
#  '603050.SH.csv',
#  '000697.SZ.csv',
#  '002495.SZ.csv',
#  '600678.SH.csv',
#  '300520.SZ.csv',
#  '600030.SH.csv',
#  '002243.SZ.csv',
#  '300049.SZ.csv',
#  '300122.SZ.csv',
#  '000737.SZ.csv',
#  '002737.SZ.csv',
#  '002202.SZ.csv',
#  '000719.SZ.csv',
#  '300695.SZ.csv',
#  '603616.SH.csv',
#  '601066.SH.csv',
#  '002063.SZ.csv',
#  '600332.SH.csv',
#  '600243.SH.csv',
#  '603797.SH.csv',
#  '000546.SZ.csv',
#  '002162.SZ.csv',
#  '600082.SH.csv',
#  '603838.SH.csv',
#  '002219.SZ.csv',
#  '600159.SH.csv',
#  '300034.SZ.csv',
#  '000417.SZ.csv',
#  '603939.SH.csv',
#  '600327.SH.csv',
#  '603016.SH.csv',
#  '300467.SZ.csv',
#  '002133.SZ.csv',
#  '601311.SH.csv',
#  '000965.SZ.csv',
#  '002879.SZ.csv',
#  '300466.SZ.csv',
#  '300592.SZ.csv',
#  '002117.SZ.csv',
#  '002342.SZ.csv',
#  '600509.SH.csv',
#  '601228.SH.csv',
#  '300408.SZ.csv',
#  '000586.SZ.csv',
#  '000612.SZ.csv',
#  '603185.SH.csv',
#  '300506.SZ.csv',
#  '300661.SZ.csv',
#  '002717.SZ.csv',
#  '002454.SZ.csv',
#  '600467.SH.csv',
#  '300503.SZ.csv',
#  '000615.SZ.csv',
#  '002808.SZ.csv',
#  '603289.SH.csv',
#  '600138.SH.csv',
#  '300418.SZ.csv',
#  '600550.SH.csv',
#  '603335.SH.csv',
#  '002795.SZ.csv',
#  '600763.SH.csv',
#  '002227.SZ.csv',
#  '600679.SH.csv',
#  '000897.SZ.csv',
#  '001896.SZ.csv',
#  '002023.SZ.csv',
#  '002621.SZ.csv',
#  '300066.SZ.csv',
#  '600784.SH.csv',
#  '600212.SH.csv',
#  '603833.SH.csv',
#  '002361.SZ.csv',
#  '000695.SZ.csv',
#  '603030.SH.csv',
#  '600582.SH.csv',
#  '300163.SZ.csv',
#  '600512.SH.csv',
#  '600516.SH.csv',
#  '603967.SH.csv',
#  '300775.SZ.csv',
#  '601999.SH.csv',
#  '002841.SZ.csv',
#  '600983.SH.csv',
#  '002769.SZ.csv',
#  '002418.SZ.csv',
#  '002813.SZ.csv',
#  '603856.SH.csv',
#  '300164.SZ.csv',
#  '601890.SH.csv',
#  '600960.SH.csv',
#  '300100.SZ.csv',
#  '000758.SZ.csv',
#  '300640.SZ.csv',
#  '600345.SH.csv',
#  '300298.SZ.csv',
#  '000602.SZ.csv',
#  '000899.SZ.csv',
#  '600167.SH.csv',
#  '002201.SZ.csv',
#  '300458.SZ.csv',
#  '002255.SZ.csv',
#  '300354.SZ.csv',
#  '300727.SZ.csv',
#  '002339.SZ.csv',
#  '600149.SH.csv',
#  '300069.SZ.csv',
#  '600892.SH.csv',
#  '002187.SZ.csv',
#  '002213.SZ.csv',
#  '600600.SH.csv',
#  '601158.SH.csv',
#  '000702.SZ.csv',
#  '600058.SH.csv',
#  '000005.SZ.csv',
#  '300018.SZ.csv',
#  '600895.SH.csv',
#  '000989.SZ.csv',
#  '603200.SH.csv',
#  '002741.SZ.csv',
#  '300152.SZ.csv',
#  '603100.SH.csv',
#  '002790.SZ.csv',
#  '300637.SZ.csv',
#  '601636.SH.csv',
#  '300411.SZ.csv',
#  '002183.SZ.csv',
#  '600113.SH.csv',
#  '300024.SZ.csv',
#  '002713.SZ.csv',
#  '000929.SZ.csv',
#  '000010.SZ.csv',
#  '603557.SH.csv',
#  '600978.SH.csv',
#  '300293.SZ.csv',
#  '002167.SZ.csv',
#  '600515.SH.csv',
#  '002565.SZ.csv',
#  '002859.SZ.csv',
#  '600129.SH.csv',
#  '002328.SZ.csv',
#  '600610.SH.csv',
#  '600029.SH.csv',
#  '600805.SH.csv',
#  '300335.SZ.csv',
#  '000632.SZ.csv',
#  '300253.SZ.csv',
#  '002699.SZ.csv',
#  '300414.SZ.csv',
#  '002147.SZ.csv',
#  '002502.SZ.csv',
#  '000501.SZ.csv',
#  '601898.SH.csv',
#  '300399.SZ.csv',
#  '300692.SZ.csv',
#  '002283.SZ.csv',
#  '002601.SZ.csv',
#  '603586.SH.csv',
#  '603367.SH.csv',
#  '000652.SZ.csv',
#  '300198.SZ.csv',
#  '300583.SZ.csv',
#  '300244.SZ.csv',
#  '600021.SH.csv',
#  '300439.SZ.csv',
#  '603733.SH.csv',
#  '002951.SZ.csv',
#  '603629.SH.csv',
#  '002018.SZ.csv',
#  '600423.SH.csv',
#  '000761.SZ.csv',
#  '002174.SZ.csv',
#  '603858.SH.csv',
#  '603187.SH.csv',
#  '002041.SZ.csv',
#  '002416.SZ.csv',
#  '600307.SH.csv',
#  '000017.SZ.csv',
#  '300743.SZ.csv',
#  '603676.SH.csv',
#  '600971.SH.csv',
#  '600778.SH.csv',
#  '300311.SZ.csv',
#  '002752.SZ.csv',
#  '603956.SH.csv',
#  '600135.SH.csv',
#  '002494.SZ.csv',
#  '600716.SH.csv',
#  '000522.SZ.csv',
#  '002071.SZ.csv',
#  '002137.SZ.csv',
#  '600189.SH.csv',
#  '002654.SZ.csv',
#  '000810.SZ.csv',
#  '002528.SZ.csv',
#  '002124.SZ.csv',
#  '600666.SH.csv',
#  '000993.SZ.csv',
#  '600721.SH.csv',
#  '600141.SH.csv',
#  '002942.SZ.csv',
#  '600180.SH.csv',
#  '601607.SH.csv',
#  '000521.SZ.csv',
#  '002440.SZ.csv',
#  '603038.SH.csv',
#  '600522.SH.csv',
#  '603583.SH.csv',
#  '300593.SZ.csv',
#  '600365.SH.csv',
#  '002364.SZ.csv',
#  '002091.SZ.csv',
#  '600469.SH.csv',
#  '300054.SZ.csv',
#  '002056.SZ.csv',
#  '300672.SZ.csv',
#  '600801.SH.csv',
#  '600459.SH.csv',
#  '300135.SZ.csv',
#  '603898.SH.csv',
#  '002486.SZ.csv',
#  '600066.SH.csv',
#  '600595.SH.csv',
#  '300042.SZ.csv',
#  '002821.SZ.csv',
#  '600661.SH.csv',
#  '300191.SZ.csv',
#  '603005.SH.csv',
#  '603600.SH.csv',
#  '300460.SZ.csv',
#  '603315.SH.csv',
#  '002691.SZ.csv',
#  '002590.SZ.csv',
#  '600901.SH.csv',
#  '002531.SZ.csv',
#  '000505.SZ.csv',
#  '002797.SZ.csv',
#  '603712.SH.csv',
#  '300078.SZ.csv',
#  '002835.SZ.csv',
#  '002347.SZ.csv',
#  '600448.SH.csv',
#  '002822.SZ.csv',
#  '300694.SZ.csv',
#  '300745.SZ.csv',
#  '600482.SH.csv',
#  '600810.SH.csv',
#  '000936.SZ.csv',
#  '002166.SZ.csv',
#  '600490.SH.csv',
#  '300565.SZ.csv',
#  '300289.SZ.csv',
#  '002733.SZ.csv',
#  '300371.SZ.csv',
#  '600377.SH.csv',
#  '300706.SZ.csv',
#  '002939.SZ.csv',
#  '002472.SZ.csv',
#  '601600.SH.csv',
#  '600766.SH.csv',
#  '300090.SZ.csv',
#  '002543.SZ.csv',
#  '002148.SZ.csv',
#  '300457.SZ.csv',
#  '600599.SH.csv',
#  '300601.SZ.csv',
#  '300278.SZ.csv',
#  '600731.SH.csv',
#  '600548.SH.csv',
#  '002125.SZ.csv',
#  '002348.SZ.csv',
#  '000976.SZ.csv',
#  '300679.SZ.csv',
#  '603517.SH.csv',
#  '300232.SZ.csv',
#  '600966.SH.csv',
#  '600419.SH.csv',
#  '002068.SZ.csv',
#  '002490.SZ.csv',
#  '603690.SH.csv',
#  '002156.SZ.csv',
#  '601028.SH.csv',
#  '002702.SZ.csv',
#  '600210.SH.csv',
#  '000002.SZ.csv',
#  '600756.SH.csv',
#  '300755.SZ.csv',
#  '300092.SZ.csv',
#  '600078.SH.csv',
#  '000756.SZ.csv',
#  '002917.SZ.csv',
#  '002479.SZ.csv',
#  '000030.SZ.csv',
#  '000006.SZ.csv',
#  '000011.SZ.csv',
#  '600389.SH.csv',
#  '300147.SZ.csv',
#  '000627.SZ.csv',
#  '603398.SH.csv',
#  '002448.SZ.csv',
#  '603718.SH.csv',
#  '300599.SZ.csv',
#  '002705.SZ.csv',
#  '300228.SZ.csv',
#  '603989.SH.csv',
#  '600401.SH.csv',
#  '300376.SZ.csv',
#  '300736.SZ.csv',
#  '300237.SZ.csv',
#  '002232.SZ.csv',
#  '300530.SZ.csv',
#  '002094.SZ.csv',
#  '600958.SH.csv',
#  '300120.SZ.csv',
#  '002875.SZ.csv',
#  '600775.SH.csv',
#  '300243.SZ.csv',
#  '600587.SH.csv',
#  '300008.SZ.csv',
#  '300705.SZ.csv',
#  '603758.SH.csv',
#  '601888.SH.csv',
#  '000883.SZ.csv',
#  '603603.SH.csv',
#  '300729.SZ.csv',
#  '002239.SZ.csv',
#  '002001.SZ.csv',
#  '002619.SZ.csv',
#  '300558.SZ.csv',
#  '603306.SH.csv',
#  '601319.SH.csv',
#  '002852.SZ.csv',
#  '603666.SH.csv',
#  '600198.SH.csv',
#  '002508.SZ.csv',
#  '300256.SZ.csv',
#  '002246.SZ.csv',
#  '000713.SZ.csv',
#  '300320.SZ.csv',
#  '000782.SZ.csv',
#  '600293.SH.csv',
#  '600160.SH.csv',
#  '000673.SZ.csv',
#  '600279.SH.csv',
#  '601985.SH.csv',
#  '600812.SH.csv',
#  '002748.SZ.csv',
#  '300427.SZ.csv',
#  '300143.SZ.csv',
#  '300742.SZ.csv',
#  '300334.SZ.csv',
#  '002938.SZ.csv',
#  '300145.SZ.csv',
#  '300249.SZ.csv',
#  '002131.SZ.csv',
#  '601229.SH.csv',
#  '600098.SH.csv',
#  '000720.SZ.csv',
#  '002718.SZ.csv',
#  '300218.SZ.csv',
#  '000938.SZ.csv',
#  '603477.SH.csv',
#  '300385.SZ.csv',
#  '002740.SZ.csv',
#  '000692.SZ.csv',
#  '600234.SH.csv',
#  '002889.SZ.csv',
#  '603559.SH.csv',
#  '600016.SH.csv',
#  '002256.SZ.csv',
#  '600372.SH.csv',
#  '600677.SH.csv',
#  '600613.SH.csv',
#  '300030.SZ.csv',
#  '603303.SH.csv',
#  '002913.SZ.csv',
#  '601555.SH.csv',
#  '600087.SH.csv',
#  '002831.SZ.csv',
#  '002553.SZ.csv',
#  '603037.SH.csv',
#  '603799.SH.csv',
#  '300619.SZ.csv',
#  '600967.SH.csv',
#  '002660.SZ.csv',
#  '603686.SH.csv',
#  '002261.SZ.csv',
#  '600881.SH.csv',
#  '600215.SH.csv',
#  '300587.SZ.csv',
#  '002809.SZ.csv',
#  '603378.SH.csv',
#  '300265.SZ.csv',
#  '600822.SH.csv',
#  '600104.SH.csv',
#  '600340.SH.csv',
#  '002171.SZ.csv',
#  '300369.SZ.csv',
#  '300420.SZ.csv',
#  '300444.SZ.csv',
#  '300082.SZ.csv',
#  '603579.SH.csv',
#  '600019.SH.csv',
#  '000796.SZ.csv',
#  '300602.SZ.csv',
#  '002197.SZ.csv',
#  '300495.SZ.csv',
#  '002662.SZ.csv',
#  '002878.SZ.csv',
#  '300173.SZ.csv',
#  '300469.SZ.csv',
#  '600827.SH.csv',
#  '603698.SH.csv',
#  '600724.SH.csv',
#  '603268.SH.csv',
#  '300134.SZ.csv',
#  '600460.SH.csv',
#  '603238.SH.csv',
#  '600475.SH.csv',
#  '600339.SH.csv',
#  '600734.SH.csv',
#  '002437.SZ.csv',
#  '600466.SH.csv',
#  '300675.SZ.csv',
#  '002281.SZ.csv',
#  '002218.SZ.csv',
#  '300215.SZ.csv',
#  '603305.SH.csv',
#  '600933.SH.csv',
#  '600338.SH.csv',
#  '600717.SH.csv',
#  '300540.SZ.csv',
#  '600560.SH.csv',
#  '002687.SZ.csv',
#  '002608.SZ.csv',
#  '603232.SH.csv',
#  '002291.SZ.csv',
#  '300528.SZ.csv',
#  '600887.SH.csv',
#  '300647.SZ.csv',
#  '300013.SZ.csv',
#  '600387.SH.csv',
#  '600037.SH.csv',
#  '603896.SH.csv',
#  '002871.SZ.csv',
#  '002599.SZ.csv',
#  '300356.SZ.csv',
#  '600990.SH.csv',
#  '300368.SZ.csv',
#  '603026.SH.csv',
#  '603166.SH.csv',
#  '002272.SZ.csv',
#  '600549.SH.csv',
#  '002280.SZ.csv',
#  '603839.SH.csv',
#  '603881.SH.csv',
#  '600821.SH.csv',
#  '000885.SZ.csv',
#  '600760.SH.csv',
#  '002439.SZ.csv',
#  '300039.SZ.csv',
#  '002326.SZ.csv',
#  '600783.SH.csv',
#  '002432.SZ.csv',
#  '000831.SZ.csv',
#  '300292.SZ.csv',
#  '300169.SZ.csv',
#  '600897.SH.csv',
#  '600380.SH.csv',
#  '000611.SZ.csv',
#  '002226.SZ.csv',
#  '600981.SH.csv',
#  '002803.SZ.csv',
#  '603580.SH.csv',
#  '603937.SH.csv',
#  '300484.SZ.csv',
#  '002836.SZ.csv',
#  '600988.SH.csv',
#  '600166.SH.csv',
#  '300403.SZ.csv',
#  '600075.SH.csv',
#  '300501.SZ.csv',
#  '300001.SZ.csv',
#  '000922.SZ.csv',
#  '000523.SZ.csv',
#  '002799.SZ.csv',
#  '600789.SH.csv',
#  '000541.SZ.csv',
#  '002359.SZ.csv',
#  '002399.SZ.csv',
#  '600371.SH.csv',
#  '300607.SZ.csv',
#  '002212.SZ.csv',
#  '000876.SZ.csv',
#  '600615.SH.csv',
#  '000559.SZ.csv',
#  '300500.SZ.csv',
#  '600190.SH.csv',
#  '601515.SH.csv',
#  '600403.SH.csv',
#  '603332.SH.csv',
#  '600470.SH.csv',
#  '000727.SZ.csv',
#  '000820.SZ.csv',
#  '600571.SH.csv',
#  '002467.SZ.csv',
#  '000062.SZ.csv',
#  '603628.SH.csv',
#  '000416.SZ.csv',
#  '601689.SH.csv',
#  '300268.SZ.csv',
#  '603619.SH.csv',
#  '000510.SZ.csv',
#  '002928.SZ.csv',
#  '601018.SH.csv',
#  '600667.SH.csv',
#  '000426.SZ.csv',
#  '002273.SZ.csv',
#  '000530.SZ.csv',
#  '600346.SH.csv',
#  '300012.SZ.csv',
#  '000659.SZ.csv',
#  '300174.SZ.csv',
#  '002011.SZ.csv',
#  '002703.SZ.csv',
#  '603626.SH.csv',
#  '600206.SH.csv',
#  '002629.SZ.csv',
#  '600562.SH.csv',
#  '002409.SZ.csv',
#  '002344.SZ.csv',
#  '600854.SH.csv',
#  '601997.SH.csv',
#  '300546.SZ.csv',
#  '600705.SH.csv',
#  '600529.SH.csv',
#  '300155.SZ.csv',
#  '600223.SH.csv',
#  '000851.SZ.csv',
#  '000024.SZ.csv',
#  '603039.SH.csv',
#  '601628.SH.csv',
#  '002688.SZ.csv',
#  '002208.SZ.csv',
#  '300201.SZ.csv',
#  '002582.SZ.csv',
#  '300355.SZ.csv',
#  '000895.SZ.csv',
#  '000402.SZ.csv',
#  '002766.SZ.csv',
#  '300405.SZ.csv',
#  '002498.SZ.csv',
#  '000793.SZ.csv',
#  '603993.SH.csv',
#  '002908.SZ.csv',
#  '002430.SZ.csv',
#  '000407.SZ.csv',
#  '600319.SH.csv',
#  '000600.SZ.csv',
#  '300272.SZ.csv',
#  '600572.SH.csv',
#  '300141.SZ.csv',
#  '600184.SH.csv',
#  '002945.SZ.csv',
#  '002161.SZ.csv',
#  '000410.SZ.csv',
#  '603010.SH.csv',
#  '300337.SZ.csv',
#  '300238.SZ.csv',
#  '300081.SZ.csv',
#  '000569.SZ.csv',
#  '002614.SZ.csv',
#  '603339.SH.csv',
#  '300133.SZ.csv',
#  '600764.SH.csv',
#  '300402.SZ.csv',
#  '300724.SZ.csv',
#  '300421.SZ.csv',
#  '600472.SH.csv',
#  '000023.SZ.csv',
#  '000566.SZ.csv',
#  '600559.SH.csv',
#  '601615.SH.csv',
#  '603922.SH.csv',
#  '600276.SH.csv',
#  '600200.SH.csv',
#  '002715.SZ.csv',
#  '000792.SZ.csv',
#  '002310.SZ.csv',
#  '600676.SH.csv',
#  '603183.SH.csv',
#  '000531.SZ.csv',
#  '002323.SZ.csv',
#  '300557.SZ.csv',
#  '300358.SZ.csv',
#  '000802.SZ.csv',
#  '603080.SH.csv',
#  '603323.SH.csv',
#  '300450.SZ.csv',
#  '603976.SH.csv',
#  '000688.SZ.csv',
#  '000778.SZ.csv',
#  '002556.SZ.csv',
#  '600825.SH.csv',
#  '300260.SZ.csv',
#  '603703.SH.csv',
#  '300507.SZ.csv',
#  '600105.SH.csv',
#  '300349.SZ.csv',
#  '002465.SZ.csv',
#  '002484.SZ.csv',
#  '600301.SH.csv',
#  '603351.SH.csv',
#  '300552.SZ.csv',
#  '002058.SZ.csv',
#  '002059.SZ.csv',
#  '000623.SZ.csv',
#  '601882.SH.csv',
#  '603127.SH.csv',
#  '600108.SH.csv',
#  '002111.SZ.csv',
#  '600742.SH.csv',
#  '603987.SH.csv',
#  '603929.SH.csv',
#  '603338.SH.csv',
#  '601218.SH.csv',
#  '600823.SH.csv',
#  '600261.SH.csv',
#  '002325.SZ.csv',
#  '300522.SZ.csv',
#  '603906.SH.csv',
#  '600137.SH.csv',
#  '002336.SZ.csv',
#  '600668.SH.csv',
#  '600791.SH.csv',
#  '603013.SH.csv',
#  '601818.SH.csv',
#  '600002.SH.csv',
#  '002120.SZ.csv',
#  '601988.SH.csv',
#  '000008.SZ.csv',
#  '300098.SZ.csv',
#  '600652.SH.csv',
#  '600757.SH.csv',
#  '601002.SH.csv',
#  '000625.SZ.csv',
#  '601099.SH.csv',
#  '601886.SH.csv',
#  '002199.SZ.csv',
#  '603598.SH.csv',
#  '002774.SZ.csv',
#  '600647.SH.csv',
#  '002301.SZ.csv',
#  '000061.SZ.csv',
#  '002349.SZ.csv',
#  '603345.SH.csv',
#  '002869.SZ.csv',
#  '600523.SH.csv',
#  '300287.SZ.csv',
#  '002129.SZ.csv',
#  '603596.SH.csv',
#  '603229.SH.csv',
#  '000539.SZ.csv',
#  '300014.SZ.csv',
#  '600405.SH.csv',
#  '002141.SZ.csv',
#  '603019.SH.csv',
#  '002194.SZ.csv',
#  '002510.SZ.csv',
#  '000816.SZ.csv',
#  '300453.SZ.csv',
#  '600426.SH.csv',
#  '300550.SZ.csv',
#  '601918.SH.csv',
#  '603018.SH.csv',
#  '000422.SZ.csv',
#  '000066.SZ.csv',
#  '000155.SZ.csv',
#  '000953.SZ.csv',
#  '002905.SZ.csv',
#  '002937.SZ.csv',
#  '300343.SZ.csv',
#  '002481.SZ.csv',
#  '002002.SZ.csv',
#  '300255.SZ.csv',
#  '603025.SH.csv',
#  '300114.SZ.csv',
#  '601990.SH.csv',
#  '002054.SZ.csv',
#  '603021.SH.csv',
#  '600860.SH.csv',
#  '002686.SZ.csv',
#  '603606.SH.csv',
#  ...]

# %% [markdown]
# ### 3. 停词表中加入公司名

# %%
def get_price(symbol):
    price = updb.pull_stocks([symbol], startT='20100101').sort_index().reset_index().rename(columns={'TRADE_DT':'date',symbol:'close'})
    price['CloseRet_t-2_t+1'] = price['close'].shift(-1) / price['close'].shift(2)-1
    price['CloseRet_t-1_t+1'] = price['close'].shift(-1) / price['close'].shift(1)-1
    price['CloseRet_t_t+1'] = price['close'].shift(-1) / price['close'].shift(0)-1
    price['CloseRet_t-1_t'] = price['close'].shift(0) / price['close'].shift(1)-1
    return price

def get_label(df, indicators, thresholds):
    def assign(df, indicator,threshold):
        pos = df.loc[df[indicator]>threshold,['title','date']]
        pos['label'] = 1
        neg = df.loc[df[indicator]<-threshold,['title','date']]
        neg['label'] = 0
        df_ok = pd.concat([pos,neg])
        df_ok['title'] = [s.replace(code_name.loc[symbol].values[0],'') for s in df_ok['title']]
        return df_ok
    dfs = [assign(deepcopy(df),ind, thr) for ind,thr in zip(indicators,thresholds)]
    return dfs
    
def process(symbol, indicators, thresholds, sep_date, first=False):
    # process news
    news = pd.read_csv('../news/%s.csv' % symbol,dtype={'date':str})[['date','title','time']]
    news = news.dropna()
    news = news.sort_values('date')
    nonsense=['融资融券信息','大宗交易','今日超大单流','龙虎榜','下跌','上涨','跌幅','涨幅','涨停','跌停',
              '大涨','大跌','跳水','盘中','融资余额','反弹','回调','火箭发射']
    is_useful = np.array([not any(bool(re.search(w,l)) for w in nonsense) for l in news['title'].values])
    news = news[is_useful]
    # news['content'] = news['title'] + news['content']
    news['date'] = list(map(lambda x:x.replace('-',''), news['date'].values))

    news = news.merge(index[['date','next_date']],how='left')
    news.loc[news['time']>'13:00:00','date'] = np.nan
    news['date'] = news['date'].fillna(news['next_date'])

    price = get_price(symbol)
    news = news.merge(price)
    dfs = get_label(news, indicators, thresholds)
    
    for ind,df in zip(indicators, dfs):
        df_use = df.loc[df['date']<sep_date, ['label','title']]
        if first:
            df_use.to_csv('output/%s.csv' % ind, index=False)
        else:
            df_use.loc[df['date']<sep_date, ['label','title']].to_csv('output/%s.csv' % ind, mode='a', header=False,  index=False)
#         print('useful: %d  tot:%d' % (len(df_use),len(df)),)
#     print()
    
indicators = ['CloseRet_t-2_t+1','CloseRet_t-1_t+1','CloseRet_t_t+1']
thresholds = [0.1,0.08,0.05]
sep_date='20180101'
nf = newsfiles[0]
process(nf[:9],indicators, thresholds, sep_date, first=True)
for i,nf in enumerate(newsfiles[1:5]):
    if (len(nf)==13):
        print('processing %s %d/%d' % (nf[:9], i, len(newsfiles)))
        process(nf[:9],indicators, thresholds, sep_date, first=False)
# Out:
# processing 000935.SZ 0/3668
# processing 603798.SH 1/3668
# processing 600518.SH 2/3668
# processing 300515.SZ 3/3668
