# %%
import re
import pandas as pd
from sqlalchemy import create_engine
from pymysql import connect

# %%
NONSENSE=['融资融券信息','融资净偿还','融资净买入','融券净偿还','大宗交易','今日超大单流','龙虎榜','下跌','上涨','跌幅',
          '涨幅','涨停','跌停','大涨','大跌','跳水','盘中','融资余额','反弹','回调','火箭发射','投资者关系']

mysql_conn = create_engine('mysql://wy:,.,.,l@10.24.224.249/webdata?charset=utf8')
df = pd.read_sql('select TITLE, URL from EastMoney where USEFUL is NULL limit 10',mysql_conn)
conn = connect(host='10.24.224.249', port=3306, database='webdata', user='wy',password=',.,.,l', charset='utf8')
cur = conn.cursor()
cnt = 0
while len(df) != 0:
    for url,title in zip(df['URL'], df['TITLE']):
        is_useful = int(not ((len(title.strip())==0) or any([bool(re.search(w,title)) for w in NONSENSE]) ))
        sql = "update EastMoney set USEFUL=%d where URL=\'%s\'" % (is_useful, url)
        cur.execute(sql)
        cnt += 1
        if cnt % 1000 == 0:
            print('finish %d' % cnt)
    df = pd.read_sql('select TITLE, URL from EastMoney where USEFUL is NULL limit 10',mysql_conn)
# Out:
# finish 1000
# finish 2000
# finish 3000
# finish 4000
# finish 5000
# finish 6000
# finish 7000
# finish 8000
# finish 9000
# finish 10000
# finish 11000
# finish 12000
# finish 13000
# finish 14000
# finish 15000
# finish 16000
# finish 17000
# finish 18000
# finish 19000
# finish 20000
# finish 21000
# finish 22000
# finish 23000
# finish 24000
# finish 25000
# finish 26000
# finish 27000
# finish 28000
# finish 29000
# finish 30000
# finish 31000
# finish 32000
# finish 33000
# finish 34000
# finish 35000
# finish 36000
# finish 37000
# finish 38000
# finish 39000
# finish 40000
# finish 41000
# finish 42000
# finish 43000
# finish 44000
# finish 45000
# finish 46000
# finish 47000
# finish 48000
# finish 49000
# finish 50000
# finish 51000
# finish 52000
# finish 53000
# finish 54000
# finish 55000
# finish 56000
# finish 57000
# finish 58000
# finish 59000
# finish 60000
# finish 61000
# finish 62000
# finish 63000
# finish 64000
# finish 65000
# finish 66000
# finish 67000
# ...
